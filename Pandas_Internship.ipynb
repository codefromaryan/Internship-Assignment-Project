# %%
import pandas as pd

# %%
data = {
    'Name' : ['John', 'Jane', 'Bob', 'Alice'],
    'Age' : [25, 30, 35, 40],
    'City' : ['New York', 'Paris', 'London', 'Sydney']
}

print(data)
# Out:
# {'Name': ['John', 'Jane', 'Bob', 'Alice'], 'Age': [25, 30, 35, 40], 'City': ['New York', 'Paris', 'London', 'Sydney']}

# %%
for key, value in data.items():
  print(f"{key}: {value}")
# Out:
# Name: ['John', 'Jane', 'Bob', 'Alice']
# Age: [25, 30, 35, 40]
# City: ['New York', 'Paris', 'London', 'Sydney']

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1   Jane   30     Paris
# 2    Bob   35    London
# 3  Alice   40    Sydney

# %%
dataset = pd.read_csv('Data.csv')
print(dataset)
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dataset.describe().T
# Out:
#         count          mean           std      min      25%      50%      75%  \
# Age       9.0     38.777778      7.693793     27.0     35.0     38.0     44.0
# Salary    9.0  63777.777778  12265.579662  48000.0  54000.0  61000.0  72000.0
#
#             max
# Age        50.0
# Salary  83000.0

# %%
dataset.describe(include = 'O').T
# Out:
#           count unique     top freq
# Country      10      3  France    4
# Purchased    10      2      No    5
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('unique').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_1.groupby('top').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_2.groupby('freq').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d categorical distributions</h4>
# <style>
# ...

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1   Jane   30     Paris
# 2    Bob   35    London
# 3  Alice   40    Sydney

# %%
df['Age']
# Out:
# 0    25
# 1    30
# 2    35
# 3    40
# Name: Age, dtype: int64

# %%
#.iloc and loc [row : column]
#',' for indivisual value
#':' for range value
df.iloc[[0,2] ,[0,1]]
# Out:
#    Name  Age
# 0  John   25
# 2   Bob   35

# %%
df.loc[2, 'Name'] #loc we use as column name
# Out:
# 'Bob'

# %% [markdown]
# Filtering Data

# %%
df
# Out:
#     Name  Age      City
# 0   John   25  New York
# 1   Jane   30     Paris
# 2    Bob   35    London
# 3  Alice   40    Sydney

# %%
df[df['Age']> 32]
# Out:
#     Name  Age    City
# 2    Bob   35  London
# 3  Alice   40  Sydney

# %% [markdown]
# Modifying

# %%
df['Age'] = df['Age'] +10
df
# Out:
#     Name  Age      City
# 0   John   45  New York
# 1   Jane   50     Paris
# 2    Bob   55    London
# 3  Alice   60    Sydney

# %%
df['Wife'] = ['Sandra', 'Alice', 'Charliee', 'Astra']
df
# Out:
#     Name  Age      Wife
# 0   John   45    Sandra
# 1   Jane   50     Alice
# 2    Bob   55  Charliee
# 3  Alice   60     Astra

# %%
df.drop(columns = ['Wife'])
# Out:
#     Name  Age
# 0   John   45
# 1   Jane   50
# 2    Bob   55
# 3  Alice   60

# %%
df['Wife'] = ['Sandra', 'Alice', 'Charliee', 'Astra']
df['Salary'] = [50000, 60000, 70000, 80000]

# %%
dataset
# Out:
#    Country   Age   Salary Purchased
# 0   France  44.0  72000.0        No
# 1    Spain  27.0  48000.0       Yes
# 2  Germany  30.0  54000.0        No
# 3    Spain  38.0  61000.0        No
# 4  Germany  40.0      NaN       Yes
# 5   France  35.0  58000.0       Yes
# 6    Spain   NaN  52000.0        No
# 7   France  48.0  79000.0       Yes
# 8  Germany  50.0  83000.0        No
# 9   France  37.0  67000.0       Yes

# %%
dataset.groupby('Country')['Age'].mean()
# Out:
# Country
# France     41.0
# Germany    40.0
# Spain      32.5
# Name: Age, dtype: float64

# %%
df.to_csv('New.csv')

# %%
df['Salary'].apply(lambda x:x**2),
# Out:
# (0    2500000000
#  1    3600000000
#  2    4900000000
#  3    6400000000
#  Name: Salary, dtype: int64,)

# %%
df.set_index('Salary', inplace = True)

# %%
df
# Out:
#          Name  Age      Wife
# Salary
# 50000    John   45    Sandra
# 60000    Jane   50     Alice
# 70000     Bob   55  Charliee
# 80000   Alice   60     Astra

# %%
data = {
    'Name' : ['John', 'Jane', 'Bob', 'Alice'],
    'Age' : [25, 30, 35, 40],
    'City' : ['New York', 'Paris', 'London', 'Sydney']
}

df = pd.DataFrame(data)

# %%
df2 = {
    'New Name' : ['Larry', 'Barry', 'Carter', 'Holly'],
    'Age' : [25, 30, 35, 40],
    'City' : ['New York', 'Paris', 'London', 'Sydney']
}
df2 = pd.DataFrame(df2)

# %%
pd.merge(df,df2,on = 'Age')
# Out:
#     Name  Age    City_x New Name    City_y
# 0   John   25  New York    Larry  New York
# 1   Jane   30     Paris    Barry     Paris
# 2    Bob   35    London   Carter    London
# 3  Alice   40    Sydney    Holly    Sydney
